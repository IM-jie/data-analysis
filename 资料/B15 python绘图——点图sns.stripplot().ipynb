# %% [markdown]
# # 点图

# %% [markdown]
# **点图（Strip Plot）**是一种分类数据可视化方式，会将每个数据点沿着一个轴方向排列。与散点图相比，点图特别适用于对离散数据的可视化展示。

# %% [markdown]
# ## 适用场景

# %% [markdown]
# - 离散数据展示：点图适用于展示每个类别下的数值分布情况。
# - 查看离群点：点图可以帮助识别数据中的异常值或离群点，因为每个数据点都会单独显示。
# - 小型数据集：点图特别适合于样本较少的数据集，能够精确地展示每个数据点。

# %% [markdown]
# ## sns.stripplot

# %% [markdown]
# - `data`: 要绘制的数据集，DataFrame
# - `x`: x轴变量名称。
# - `y`: y轴变量名称。
# - `hue`: 用于分组的变量，可以按分类变量显示不同的颜色。
# - `jitter`: 是否在 x 轴上加入轻微的随机偏移，使得数据点不会完全重叠。设置为 True 可以让点图更易于观察。
# - `dodge`: 如果 hue 参数被使用，dodge=True 会将数据点根据 hue 分类分开，防止重叠。默认情况下，dodge=False，所有点会堆叠在一起。
# - `palette`: 设置颜色调色板。
# - `size`: 数据点的大小，默认为 5。

# %% [markdown]
# ## 点图案例

# %% [markdown]
# **tips**: 餐饮小费数据集
# - total_bill：账单金额
# - tip：小费金额
# - sex：性别（Male 或 Female）
# - smoker：是否吸烟（Yes 或 No）
# - day：星期几（Sun, Thu, Fri, Sat）
# - time：就餐时间（Lunch 或 Dinner）
# - size：就餐人数

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 加载示例数据
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 基本点图

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和日期之间的关系
sns.stripplot(data=tips, x='day', y='total_bill')

# 设置图表标题和标签
plt.title('Total Bill vs. Day', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()

# %% [markdown]
# ### hue-根据分组变量进行着色

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和小费之间的关系
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex')

# 设置图表标题和标签
plt.title('Total Bill by Day and Sex', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()

# %% [markdown]
# ### jitter-是否加入随机偏移

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和小费之间的关系
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex', jitter=True)

# 设置图表标题和标签
plt.title('Total Bill by Day and Sex', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()

# %% [markdown]
# ### dodge-是否根据hue将数据点分开

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和小费之间的关系
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex', jitter=True, dodge=True)

# 设置图表标题和标签
plt.title('Total Bill by Day and Sex', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()

# %% [markdown]
# ### palette-设置调色板

# %% [markdown]
# #### 常见颜色调色板palette介绍

# %% [markdown]
# **Qualitative Palettes**：适合离散的类别数据，颜色彼此之间没有顺序或关联。
#
# - 'deep'：默认的调色板，适合大部分情况。
# - 'muted'：颜色较为柔和，适合多个类别的对比。
# - 'pastel'：较为柔和的颜色，视觉上不那么刺眼。
# - 'dark'：较为深沉的颜色，适合正式的图表。
# - 'colorblind'：设计考虑到色盲友好，适合需要考虑视觉障碍的用户。
# - 'Set1', 'Set2', 'Set3'：非常适合多个类别的颜色分配。
# - 'Paired'：适合两两配对的颜色。
# - 'Accent'：色调较鲜艳，适合强调特定类别。
#
# **Sequential Palettes**：适合连续数据的颜色映射，从浅色到深色表示数据的从小到大的变化。
#
# - 'Blues'：从浅蓝色到深蓝色。
# - 'Greens'：从浅绿色到深绿色。
# - 'Reds'：从浅红色到深红色。
# - 'Purples'：从浅紫色到深紫色。
# - 'YlGn'、'YlGnBu' 等：从黄色到绿色或蓝色。
# - 'Oranges'、'YlOrBr'：从浅橙色到深橙色。
# - 'BuGn'、'BuPu'：从浅蓝色到紫色等。
#
# **Diverging Palettes**：适合表示有中值的连续数据，颜色从两端扩展到中间。
#
# - 'RdBu'：从红色到蓝色，适合表示负值和正值。
# - 'RdYlBu'：从红色到黄色再到蓝色，适合显示中立值。
# - 'Spectral'：从紫色到蓝色再到红色，适合强烈的对比。
#
# **Cyclic Palettes**：适合具有周期性的数据，颜色从一个极端到另一个极端，然后回到第一个极端。
#
# - 'twilight'、'twilight_shifted'：常用于时间序列数据。

# %% [markdown]
# #### 不同palette调色板案例

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和小费之间的关系
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex', jitter=True, dodge=True, palette='Set1')

# 设置图表标题和标签
plt.title('Total Bill by Day and Sex', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()

# %% [markdown]
# ### size-设置点的大小

# %%
# 设置Seaborn的风格和颜色调色板
sns.set_style("darkgrid")

# 设置图片大小
plt.figure(figsize=(8, 6))  # 设置宽8英寸，高6英寸

# 绘制点图，展示总账单金额和小费之间的关系
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex', jitter=True, dodge=True, palette='Set1', size=5)

# 设置图表标题和标签
plt.title('Total Bill by Day and Sex', fontsize=16, fontweight='bold')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')

# 渲染、显示图表
plt.show()
